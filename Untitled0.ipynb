# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sales_data (1).csv')
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df[['Unit_Cost','Unit_Price','Profit']].mean()
# Out:
# Unit_Cost     267.296366
# Unit_Price    452.938427
# Profit        285.051665
# dtype: float64

# %%
df['Product_Category'].unique()
# Out:
# array(['Accessories', 'Clothing', 'Bikes'], dtype=object)

# %%
df.groupby('Product_Category')['Order_Quantity'].sum().sort_values(ascending=False).head()
# Out:
# Product_Category
# Accessories    1054162
# Clothing        254743
# Bikes            36411
# Name: Order_Quantity, dtype: int64

# %%
df.groupby('Product_Category')['Profit'].sum().sort_values(ascending=False).head()
# Out:
# Product_Category
# Bikes          20519276
# Accessories     8862377
# Clothing        2839447
# Name: Profit, dtype: int64

# %%
df['Customer_Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
df.groupby('Country')['Revenue'].max().sort_values(ascending=False).head()
# Out:
# Country
# Australia        58074
# Canada           14312
# Germany          14169
# United States    14026
# France           13740
# Name: Revenue, dtype: int64

# %%
df.groupby('Age_Group')['Revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# Age_Group
# Adults (35-64)          42584153
# Young Adults (25-34)    30655614
# Youth (<25)             11723199
# Seniors (64+)             308042
# Name: Revenue, dtype: int64

# %%
# profit comparison across product caegories by gender
pd.pivot_table(df, values="Profit", index="Product_Category", columns="Customer_Gender", aggfunc="mean")
# Out:
# Customer_Gender            F           M
# Product_Category
# Accessories       122.858586  129.682187
# Bikes             798.940865  780.753085
# Clothing          162.911560  171.973164

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=42)

# Convert to DataFrame
df = pd.DataFrame(X, columns=['Product_Category', 'Feature2'])
print(df.head())
# Out:
#    Age_Group   Product
# 0  -9.113944  6.813616
# 1  -9.354576  7.092790
# 2  -2.015671  8.281780
# 3  -7.010236 -6.220843
# 4 -10.061202  6.718671

# %%
df['Cluster'] = kmeans.labels_

# %%
# --- Import Libraries ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# --- Load Data ---
df = pd.read_csv('/content/sales_data (1).csv')

# --- Select Features for Clustering ---
X = df[['Customer_Age', 'Revenue', 'Profit']]

# --- Scale Features ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# --- Apply K-Means (3 clusters) ---
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# --- Cluster Summary ---
print("\nCluster Characteristics:")
print(df.groupby('Cluster')[['Customer_Age','Revenue','Profit']].mean())

# --- Visualization ---
plt.figure(figsize=(8,6))
plt.scatter(df['Customer_Age'], df['Revenue'], c=df['Cluster'], cmap='viridis')
plt.xlabel("Customer Age")
plt.ylabel("Revenue")
plt.title("Customer Segmentation with K-Means")
plt.colorbar(label='Cluster')
plt.show()
# Out:
# Cluster Characteristics:
#          Customer_Age      Revenue       Profit
# Cluster
# 0           47.211060   405.621648   169.426290
# 1           35.284916  3696.858528  1293.680250
# 2           28.389698   394.976990   159.200689
